# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./2022-0426-17-part.csv')

# %%
data
# Out:
#              x         y         z
# 0    -0.437500 -0.005615  0.936279
# 1    -0.434082 -0.008057  0.938965
# 2    -0.432373 -0.004639  0.942383
# 3    -0.432373 -0.010742  0.941406
# 4    -0.435791 -0.003418  0.938477
# ...        ...       ...       ...
# 1994 -0.427246  0.000000  0.940918
# 1995 -0.420898 -0.003662  0.939209
# 1996 -0.429932 -0.005859  0.938232
# 1997 -0.429932  0.000732  0.937500
# 1998 -0.427734  0.000488  0.931396
#
# [1999 rows x 3 columns]

# %%
data["t"] = pd.RangeIndex(1, len(data) + 1, step=1)
data
# Out:
#              x         y         z     t
# 0    -0.437500 -0.005615  0.936279     1
# 1    -0.434082 -0.008057  0.938965     2
# 2    -0.432373 -0.004639  0.942383     3
# 3    -0.432373 -0.010742  0.941406     4
# 4    -0.435791 -0.003418  0.938477     5
# ...        ...       ...       ...   ...
# 1994 -0.427246  0.000000  0.940918  1995
# 1995 -0.420898 -0.003662  0.939209  1996
# 1996 -0.429932 -0.005859  0.938232  1997
# 1997 -0.429932  0.000732  0.937500  1998
# 1998 -0.427734  0.000488  0.931396  1999
#
# [1999 rows x 4 columns]

# %%
plt.plot(data.t,data.x,color="blue")
plt.plot(data.t,data.y,color="red")
plt.plot(data.t,data.z,color="green")
plt.show()

# %%
plt.plot(data.t,data.x,color="blue")
plt.show()

# %%
plt.plot(data.t,data.y,color="red")
plt.show()

# %%
plt.plot(data.t,data.z,color="green")
plt.show()

# %%
data["a"]=data.x**2+data.y**2+data.z**2
data.a = data.a ** 0.5
data
# Out:
#              x         y         z     t         a
# 0    -0.437500 -0.005615  0.936279     1  1.033468
# 1    -0.434082 -0.008057  0.938965     2  1.034479
# 2    -0.432373 -0.004639  0.942383     3  1.036848
# 3    -0.432373 -0.010742  0.941406     4  1.036006
# 4    -0.435791 -0.003418  0.938477     5  1.034729
# ...        ...       ...       ...   ...       ...
# 1994 -0.427246  0.000000  0.940918  1995  1.033376
# 1995 -0.420898 -0.003662  0.939209  1996  1.029214
# 1996 -0.429932 -0.005859  0.938232  1997  1.032064
# 1997 -0.429932  0.000732  0.937500  1998  1.031382
# 1998 -0.427734  0.000488  0.931396  1999  1.024918
#
# [1999 rows x 5 columns]

# %%
plt.plot(data.t,data.a,color="blue")
plt.show()

# %%
data.a.describe()
# Out:
# count    1999.000000
# mean        1.033390
# std         0.003301
# min         1.019971
# 25%         1.031195
# 50%         1.033398
# 75%         1.035558
# max         1.043977
# Name: a, dtype: float64

# %%
data.a.hist()
# Out:
# <Axes: >

# %%
data.a.hist(bins=20)
# Out:
# <Axes: >
