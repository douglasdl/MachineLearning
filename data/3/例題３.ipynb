# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./2022-0426-17.csv')
data
# Out:
#                 x         y         z
# 0       -0.434814 -0.001709  0.943604
# 1       -0.433838 -0.005371  0.944824
# 2       -0.430664 -0.001465  0.940186
# 3       -0.430176 -0.008301  0.935303
# 4       -0.430176 -0.003174  0.940430
# ...           ...       ...       ...
# 1048570 -0.998535 -0.019043  0.086426
# 1048571 -1.001221 -0.020020  0.082764
# 1048572 -0.996094 -0.019043  0.081055
# 1048573 -0.996826 -0.016357  0.082275
# 1048574 -0.995850 -0.011719  0.083984
#
# [1048575 rows x 3 columns]

# %%
data["t"] = pd.RangeIndex(1, len(data) + 1, step=1)
data
# Out:
#                 x         y         z        t
# 0       -0.434814 -0.001709  0.943604        1
# 1       -0.433838 -0.005371  0.944824        2
# 2       -0.430664 -0.001465  0.940186        3
# 3       -0.430176 -0.008301  0.935303        4
# 4       -0.430176 -0.003174  0.940430        5
# ...           ...       ...       ...      ...
# 1048570 -0.998535 -0.019043  0.086426  1048571
# 1048571 -1.001221 -0.020020  0.082764  1048572
# 1048572 -0.996094 -0.019043  0.081055  1048573
# 1048573 -0.996826 -0.016357  0.082275  1048574
# 1048574 -0.995850 -0.011719  0.083984  1048575
#
# [1048575 rows x 4 columns]

# %%
plt.plot(data.t,data.x,color="blue")
plt.plot(data.t,data.y,color="red")
plt.plot(data.t,data.z,color="green")
plt.show()

# %%
plt.plot(data.t,data.x,color="blue")
plt.show()

# %%
plt.plot(data.t,data.y,color="red")
plt.show()

# %%
plt.plot(data.t,data.z,color="green")
plt.show()

# %%
data["a"]=data.x**2+data.y**2+data.z**2
data.a = data.a ** 0.5
data
# Out:
#                 x         y         z        t         a
# 0       -0.434814 -0.001709  0.943604        1  1.038968
# 1       -0.433838 -0.005371  0.944824        2  1.039681
# 2       -0.430664 -0.001465  0.940186        3  1.034129
# 3       -0.430176 -0.008301  0.935303        4  1.029520
# 4       -0.430176 -0.003174  0.940430        5  1.034151
# ...           ...       ...       ...      ...       ...
# 1048570 -0.998535 -0.019043  0.086426  1048571  1.002449
# 1048571 -1.001221 -0.020020  0.082764  1048572  1.004835
# 1048572 -0.996094 -0.019043  0.081055  1048573  0.999568
# 1048573 -0.996826 -0.016357  0.082275  1048574  1.000350
# 1048574 -0.995850 -0.011719  0.083984  1048575  0.999453
#
# [1048575 rows x 5 columns]

# %%
plt.plot(data.t,data.a,color="blue")
plt.show()

# %%
data.a.describe()
# Out:
# count    1.048575e+06
# mean     1.024131e+00
# std      1.016889e-01
# min      9.632825e-02
# 25%      1.001143e+00
# 50%      1.007599e+00
# 75%      1.038192e+00
# max      3.464066e+00
# Name: a, dtype: float64

# %%
data.a.hist()
# Out:
# <Axes: >

# %%
data.a.hist(bins=50)
# Out:
# <Axes: >

# %%
data.a.hist(range=(0.95,1.1),bins=50)
# Out:
# <Axes: >
