# %%
# ライブラリの読み込み
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping

np.random.seed(123)
tf.random.set_seed(123)

# %%
#2. データを準備する
def sin(x, T=100):
    return np.sin(2.0 * np.pi * x / T)

def toy_problem(T=100, ampl=0.05):
    x = np.arange(0, 2*T + 1)
    noise = ampl * np.random.uniform(low=-1.0, high=1.0,
                                     size=len(x))
    return sin(x) + noise

T = 100
f = toy_problem(T).astype(np.float32)
length_of_sequences = len(f)

# %%
#3.データの確認
plt.plot(range(length_of_sequences), f)
plt.show()

# %%
#4. 教師データと評価データを作成
maxlen = 25

x = []
t = []

for i in range(length_of_sequences - maxlen):
    x.append(f[i:i+maxlen])
    t.append(f[i+maxlen])

x = np.array(x).reshape(-1, maxlen, 1)
t = np.array(t).reshape(-1, 1)

x_train, x_val, t_train, t_val = train_test_split(x, t, test_size=0.2, shuffle=True)

# %%
# モデルの構築
model = Sequential()
model.add(LSTM(50, activation='tanh',
               recurrent_activation='sigmoid',
               kernel_initializer='glorot_normal',
               recurrent_initializer='orthogonal'))
model.add(Dense(1, activation='linear'))
optimizer = optimizers.Adam(learning_rate=0.001,
                                beta_1=0.9, beta_2=0.999, amsgrad=True)

model.compile(optimizer=optimizer,
                  loss='mean_squared_error')

# %%
#6.学習
es = EarlyStopping(monitor='val_loss',
                       patience=10,
                       mode="auto")
hist = model.fit(x_train, t_train,
                 epochs=300, batch_size=100,
                 verbose=2,
                 validation_data=(x_val, t_val),
                 callbacks=[es]
                )
# Out:
# Epoch 1/300
# 2/2 - 3s - loss: 0.4791 - val_loss: 0.3338 - 3s/epoch - 1s/step
# Epoch 2/300
# 2/2 - 0s - loss: 0.3961 - val_loss: 0.2704 - 51ms/epoch - 25ms/step
# Epoch 3/300
# 2/2 - 0s - loss: 0.3240 - val_loss: 0.2166 - 65ms/epoch - 33ms/step
# Epoch 4/300
# 2/2 - 0s - loss: 0.2644 - val_loss: 0.1717 - 50ms/epoch - 25ms/step
# Epoch 5/300
# 2/2 - 0s - loss: 0.2119 - val_loss: 0.1359 - 50ms/epoch - 25ms/step
# Epoch 6/300
# 2/2 - 0s - loss: 0.1704 - val_loss: 0.1098 - 50ms/epoch - 25ms/step
# Epoch 7/300
# 2/2 - 0s - loss: 0.1393 - val_loss: 0.0947 - 59ms/epoch - 29ms/step
# Epoch 8/300
# 2/2 - 0s - loss: 0.1180 - val_loss: 0.0892 - 55ms/epoch - 28ms/step
# Epoch 9/300
# 2/2 - 0s - loss: 0.1055 - val_loss: 0.0884 - 55ms/epoch - 27ms/step
# Epoch 10/300
# 2/2 - 0s - loss: 0.0983 - val_loss: 0.0875 - 54ms/epoch - 27ms/step
# Epoch 11/300
# 2/2 - 0s - loss: 0.0908 - val_loss: 0.0823 - 54ms/epoch - 27ms/step
# Epoch 12/300
# 2/2 - 0s - loss: 0.0809 - val_loss: 0.0727 - 53ms/epoch - 27ms/step
# Epoch 13/300
# 2/2 - 0s - loss: 0.0696 - val_loss: 0.0613 - 54ms/epoch - 27ms/step
# Epoch 14/300
# 2/2 - 0s - loss: 0.0593 - val_loss: 0.0498 - 54ms/epoch - 27ms/step
# Epoch 15/300
# 2/2 - 0s - loss: 0.0501 - val_loss: 0.0407 - 53ms/epoch - 26ms/step
# Epoch 16/300
# 2/2 - 0s - loss: 0.0431 - val_loss: 0.0343 - 50ms/epoch - 25ms/step
# Epoch 17/300
# 2/2 - 0s - loss: 0.0381 - val_loss: 0.0300 - 50ms/epoch - 25ms/step
# Epoch 18/300
# 2/2 - 0s - loss: 0.0343 - val_loss: 0.0269 - 51ms/epoch - 26ms/step
# Epoch 19/300
# 2/2 - 0s - loss: 0.0303 - val_loss: 0.0239 - 50ms/epoch - 25ms/step
# Epoch 20/300
# 2/2 - 0s - loss: 0.0254 - val_loss: 0.0203 - 50ms/epoch - 25ms/step
# Epoch 21/300
# 2/2 - 0s - loss: 0.0201 - val_loss: 0.0170 - 51ms/epoch - 26ms/step
# Epoch 22/300
# 2/2 - 0s - loss: 0.0151 - val_loss: 0.0159 - 50ms/epoch - 25ms/step
# Epoch 23/300
# 2/2 - 0s - loss: 0.0130 - val_loss: 0.0166 - 50ms/epoch - 25ms/step
# Epoch 24/300
# 2/2 - 0s - loss: 0.0125 - val_loss: 0.0159 - 50ms/epoch - 25ms/step
# Epoch 25/300
# 2/2 - 0s - loss: 0.0116 - val_loss: 0.0133 - 50ms/epoch - 25ms/step
# Epoch 26/300
# 2/2 - 0s - loss: 0.0099 - val_loss: 0.0109 - 67ms/epoch - 33ms/step
# Epoch 27/300
# 2/2 - 0s - loss: 0.0084 - val_loss: 0.0088 - 50ms/epoch - 25ms/step
# Epoch 28/300
# 2/2 - 0s - loss: 0.0066 - val_loss: 0.0068 - 50ms/epoch - 25ms/step
# Epoch 29/300
# 2/2 - 0s - loss: 0.0051 - val_loss: 0.0055 - 67ms/epoch - 33ms/step
# Epoch 30/300
# 2/2 - 0s - loss: 0.0040 - val_loss: 0.0048 - 51ms/epoch - 25ms/step
# Epoch 31/300
# 2/2 - 0s - loss: 0.0034 - val_loss: 0.0043 - 50ms/epoch - 25ms/step
# Epoch 32/300
# 2/2 - 0s - loss: 0.0029 - val_loss: 0.0035 - 67ms/epoch - 33ms/step
# Epoch 33/300
# 2/2 - 0s - loss: 0.0023 - val_loss: 0.0027 - 58ms/epoch - 29ms/step
# Epoch 34/300
# 2/2 - 0s - loss: 0.0019 - val_loss: 0.0020 - 55ms/epoch - 28ms/step
# Epoch 35/300
# 2/2 - 0s - loss: 0.0017 - val_loss: 0.0017 - 54ms/epoch - 27ms/step
# Epoch 36/300
# 2/2 - 0s - loss: 0.0016 - val_loss: 0.0015 - 46ms/epoch - 23ms/step
# Epoch 37/300
# 2/2 - 0s - loss: 0.0017 - val_loss: 0.0014 - 50ms/epoch - 25ms/step
# Epoch 38/300
# 2/2 - 0s - loss: 0.0017 - val_loss: 0.0014 - 50ms/epoch - 25ms/step
# Epoch 39/300
# 2/2 - 0s - loss: 0.0016 - val_loss: 0.0015 - 50ms/epoch - 25ms/step
# Epoch 40/300
# 2/2 - 0s - loss: 0.0016 - val_loss: 0.0016 - 67ms/epoch - 33ms/step
# Epoch 41/300
# 2/2 - 0s - loss: 0.0015 - val_loss: 0.0016 - 55ms/epoch - 27ms/step
# Epoch 42/300
# 2/2 - 0s - loss: 0.0014 - val_loss: 0.0016 - 54ms/epoch - 27ms/step
# Epoch 43/300
# 2/2 - 0s - loss: 0.0013 - val_loss: 0.0015 - 54ms/epoch - 27ms/step
# Epoch 44/300
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.0014 - 56ms/epoch - 28ms/step
# Epoch 45/300
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.0014 - 54ms/epoch - 27ms/step
# Epoch 46/300
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.0015 - 53ms/epoch - 27ms/step
# Epoch 47/300
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.0015 - 49ms/epoch - 24ms/step
# Epoch 48/300
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.0015 - 67ms/epoch - 33ms/step

# %%
#7.モデルの評価
sin = toy_problem(T, ampl=0.)
gen = [None for i in range(maxlen)]

z = x[:1]

# 逐次的に予測値を求める
for i in range(length_of_sequences - maxlen):
    preds = model.predict(z[-1:])
    z = np.append(z, preds)[1:]
    z = z.reshape(-1, maxlen, 1)
    gen.append(preds[0, 0])

# 予測値を可視化
plt.rc('font', family='serif')
plt.xlim([0, 2*T])
plt.ylim([-1.5, 1.5])
plt.plot(range(len(f)), sin,
         color='gray',
         linestyle='--', linewidth=0.5)
plt.plot(range(len(f)), gen,
         color='black', linewidth=1,
         marker='o', markersize=1, markerfacecolor='black',
         markeredgecolor='black')
plt.show()
# Out:
# 1/1 [==============================] - 1s 513ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
